# %%
# %pwd
# Out:
# 'd:\\parth_deshmukh\\Personal Projects\\ml_mlflow\\end_to_end_mlflow_project\\research'

# %%
import os

# %%
os.chdir("../")

# %%
# %pwd
# Out:
# 'd:\\parth_deshmukh\\Personal Projects\\ml_mlflow\\end_to_end_mlflow_project'

# %%
from dataclasses import dataclass
from pathlib import Path


@dataclass(frozen=True)
class DataTransformationConfig:
    root_dir:Path
    data_path: Path

# %%
from ml_project.constants import *
from ml_project.utils.common import read_yaml, create_directories

# %%
class ConfigurationManager:
    def __init__(
        self,
        config_filepath=CONFIG_FILE_PATH,
        params_filepath=PARAMS_FILE_PATH,
        schema_filepath=SCHEMA_FILE_PATH
    ):
        self.config = read_yaml(config_filepath)
        self.params = read_yaml(params_filepath)
        self.schema = read_yaml(schema_filepath)

        create_directories([self.config.artifacts_root])

    def get_data_transformation_config(self) -> DataTransformationConfig:
        config = self.config.data_transformation

        create_directories([config.root_dir])

        data_transformation_config = DataTransformationConfig(
            root_dir= config.root_dir,
            data_path= config.data_path
        )

        return data_transformation_config

# %%
import os
import pandas as pd
from ml_project import logger
from sklearn.model_selection import train_test_split

# %%
class DataTransformation:

    def __init__(self,config:DataTransformationConfig):
        self.config = config

    def train_test_spliting(self):
        data = pd.read_csv(self.config.data_path)
        train, test = train_test_split(data)

        train.to_csv(os.path.join(self.config.root_dir,"train.csv"), index =False)
        test.to_csv(os.path.join(self.config.root_dir,"test.csv"), index = False)

        logger.info("splitted data into training and test sets")
        logger.info(train.shape)
        logger.info(test.shape)

        print(train.shape)
        print(test.shape)

# %%
try:
    config = ConfigurationManager()
    data_transformation_config= config.get_data_transformation_config()
    data_transformation = DataTransformation(config=data_transformation_config)
    data_transformation.train_test_spliting()
except Exception as e:
    raise e
# Out:
# [2025-12-24 12:27:16,727: INFO: common: yaml file: config\config.yaml loaded sucessfully]
# [2025-12-24 12:27:16,728: INFO: common: yaml file: params.yaml loaded sucessfully]
# [2025-12-24 12:27:16,730: INFO: common: yaml file: schema.yaml loaded sucessfully]
# [2025-12-24 12:27:16,731: INFO: common: created directory at: artifacts]
# [2025-12-24 12:27:16,732: INFO: common: created directory at: artifacts/data_transformation]
# [2025-12-24 12:27:16,750: INFO: 1954816172: splitted data into training and test sets]
# [2025-12-24 12:27:16,751: INFO: 1954816172: (1199, 12)]
# [2025-12-24 12:27:16,751: INFO: 1954816172: (400, 12)]
# (1199, 12)
# (400, 12)
